# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y= np.array([5,7,9,11,13])

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n= len(x)
    learn_rt = 0.08
    plt.scatter(x,y,color='red',marker='+',linewidth='5')
    for i in range (iterations):
        y_predict = m_curr *x + b_curr
        plt.plot(x,y_predict,color='green')
        cost = (1/n) * sum (val**2 for val in (y-y_predict))
        m_derv = -(2/n)* sum (x*(y-y_predict))
        b_derv = -(2/n)* sum(y-y_predict)
        m_curr = m_curr - learn_rt *m_derv 
        b_curr = b_curr - learn_rt *b_derv
        print("m{}, b{}, cost {}, iterations{}".format (m_curr , b_curr , cost, i))

# %%
gradient_descent (x,y)
# Out:
# m4.96, b1.44, cost 89.0, iterations0
# m0.4991999999999983, b0.26879999999999993, cost 71.10560000000002, iterations1
# m4.451584000000002, b1.426176000000001, cost 56.8297702400001, iterations2
# m0.892231679999997, b0.5012275199999995, cost 45.43965675929613, iterations3
# m4.041314713600002, b1.432759910400001, cost 36.35088701894832, iterations4
# m1.2008760606719973, b0.7036872622079998, cost 29.097483330142282, iterations5
# m3.7095643080294423, b1.4546767911321612, cost 23.307872849944438, iterations6
# m1.4424862661541864, b0.881337636696883, cost 18.685758762535738, iterations7
# m3.4406683721083144, b1.4879302070713722, cost 14.994867596913156, iterations8
# m1.6308855378034224, b1.0383405553279617, cost 12.046787238456794, iterations9
# m3.2221235247119777, b1.5293810083298451, cost 9.691269350698109, iterations10
# m1.7770832372205707, b1.1780607551353204, cost 7.8084968312098315, iterations11
# ...
